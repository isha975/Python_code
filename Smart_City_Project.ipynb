# %%
import numpy as np
import seaborn as sms
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import folium as fl

# %%
data = pd.read_csv("Smart_City_index_headers.csv")
data = data.dropna()
print(data)
# Out:
#       Id           City      Country  Smart_Mobility   Smart_Environment  \
# 0      1           Oslo       Norway             6480               6512
# 1      2         Bergen       Norway             7097               6876
# 2      3      Amsterdam  Netherlands             7540               5558
# 3      4     Copenhagen      Denmark             7490               7920
# 4      5      Stockholm       Sweden             6122               7692
# ..   ...            ...          ...              ...                ...
# 97    98           Riga       Latvia             4152               4584
# 98    99        Beijing        China             7610               2998
# 99   100  St Petersburg       Russia             4588               2908
# 100  101        Calgary       Canada             6675               4052
# 101  102       Edmonton       Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0                 7516            4565          8618          9090
# 1                 7350            4905          8050          9090
# 2                 8528            8095          7098          7280
# 3                 8726            5580          5780          7200
# 4                 8354            4330          6743          7730
# ..                 ...             ...           ...           ...
# 97                4616            7380          3745          4330
# 98                2806            4905          5183          1980
# 99                3622            4515          5390          4100
# 100               5946            8022          6424          8657
# 101               6396            8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0               7138                                666
# 1               7296                                823
# 2               7311                                839
# 3               7171                                698
# 4               6812                                340
# ..               ...                                ...
# 97              4712                              -1760
# 98              4449                              -2023
# 99              4191                              -2281
# 100             6678                                206
# 101             6472                                  0
#
# [102 rows x 11 columns]

# %% [markdown]
# City: List of smart cities around the word
#
# Country: List of countries where smart cities across the world are located
#
# Smart_Mobility: Index calculated from assessment of city-wide Public Transportation System, ICT, accessibility infrastructure.
#
# Smart_Environment: Index calculated from environmental sustainability impact, monitoring pollution and energy management
#
# Smart_Government: Index calculated from comparative study of transparent governance & open data initiatives of smart cities across the
#
# Smart_Economy: Index calculated through global comparison of city-wide productivity, economic vitality, and support for entrepreneurship
#
# Smart_People: Index calculated by comparing social and cultural plurality, education systems and its supporting ancillary
#
# Smart_Living: Index calculated by measuring metric around healthcare services, social security and housing quality.
#
# SmartCity_Index: Aggregate score for smart city model based on smart city supergroups.

# %%
x = data["Country"]
y = data["Smart_People"]
bar,ax = plt.subplots(figsize = (30,50))
ax = sms.barplot(x,y,palette = "bright")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x = data["Country"]
y = data["Smart_People"]
bar,ax = plt.subplots(figsize = (30,50))
ax = sms.barplot(y,x,palette = "bright", orient = "h")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Conclusion: From both graphs displayed above we can come to the conclusion that Singapore has the most population of "Smart" People.

# %%
x = data["City"]
y = data["Smart_Mobility "]
f,ax = plt.subplots(figsize = (30,20))
sms.pointplot(x,y,color = "#4FA5FF")
plt.xticks(rotation = 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Conclusion: From the above graph, we can draw the conclusion that Naples is the city with the lowest smart mobility while Chicago is the city with the highest.

# %%
x = data["City"]
y = data["Smart_Government "]
plt.figure(figsize = (30,15))
plt.xticks(rotation = 90)
plt.plot(x,y,linewidth = 2, color = "#2EAAFF", linestyle = "-.") 
plt.scatter(x,y,color = "black")
plt.show()

# %% [markdown]
# Conclusion: The city with the smartest government was analyzed to be Copenhagen whereas on the other end of the spectrum is Beijing.

# %%
plt.figure(figsize = (50,50))
sms.pairplot(data,hue = "Country")
plt.show()

# %% [markdown]
# Conclusion: A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.

# %%
statename = data.loc[data["Country"] == "Canada"]
print(statename)
labels = statename["City"]
print(labels)
plt.figure(figsize = (10,7))
x = statename["Smart_Mobility "]
colors = np.array(["cyan", "pink", "red", "orange", "green", "purple"])
plt.pie(x,labels = labels, autopct = "%.2f", colors = colors)
plt.legend(bbox_to_anchor = (1,1))
plt.show()
# Out:
#       Id       City Country  Smart_Mobility   Smart_Environment  \
# 5      6   Montreal  Canada             7490               4848
# 14    15     Ottawa  Canada             6793               5136
# 19    20  Vancouver  Canada             5975               5348
# 21    22    Toronto  Canada             6780               4712
# 100  101    Calgary  Canada             6675               4052
# 101  102   Edmonton  Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 5                 6624            6180          8465          9920
# 14                7550            4285          6703          9920
# 19                6726            7385          7725          9920
# 21                6158            5885          7158          9920
# 100               5946            8022          6424          8657
# 101               6396            8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 5               7353                                880
# 14              6852                                379
# 19              7152                                679
# 21              6881                                409
# 100             6678                                206
# 101             6472                                  0
# 5       Montreal
# 14        Ottawa
# 19     Vancouver
# 21       Toronto
# 100      Calgary
# 101     Edmonton
# Name: City, dtype: object

# %% [markdown]
# The city in Canada with the highest social mobility is Montreal. The city with the lowest is Edmonton

# %%
x = data.groupby('Country')["Smart_Environment"].sum().sort_values(ascending = False).to_frame().reset_index()
x.style.background_gradient(cmap = "ocean")
# Out:
# <style type="text/css">
# #T_b1da7_row0_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b1da7_row1_col1 {
#   background-color: #edf6f9;
#   color: #000000;
# }
# #T_b1da7_row2_col1 {
#   background-color: #81c0d5;
#   color: #000000;
# }
# #T_b1da7_row3_col1 {
#   background-color: #0078a5;
#   color: #f1f1f1;
# }
# #T_b1da7_row4_col1 {
#   background-color: #00226c;
#   color: #f1f1f1;
# }
# #T_b1da7_row5_col1 {
#   background-color: #001b67;
#   color: #f1f1f1;
# }
# #T_b1da7_row6_col1 {
#   background-color: #000659;
#   color: #f1f1f1;
# }
# #T_b1da7_row7_col1 {
#   background-color: #000156;
#   color: #f1f1f1;
# }
# #T_b1da7_row8_col1 {
#   background-color: #00114a;
#   color: #f1f1f1;
# }
# #T_b1da7_row9_col1 {
#   background-color: #00213f;
#   color: #f1f1f1;
# }
# #T_b1da7_row10_col1 {
#   background-color: #003134;
#   color: #f1f1f1;
# }
# #T_b1da7_row11_col1 {
#   background-color: #003b2e;
#   color: #f1f1f1;
# }
# #T_b1da7_row12_col1 {
#   background-color: #00521e;
#   color: #f1f1f1;
# }
# #T_b1da7_row13_col1, #T_b1da7_row14_col1 {
#   background-color: #005c18;
#   color: #f1f1f1;
# }
# #T_b1da7_row15_col1 {
#   background-color: #006313;
#   color: #f1f1f1;
# }
# #T_b1da7_row16_col1 {
#   background-color: #006412;
#   color: #f1f1f1;
# }
# #T_b1da7_row17_col1 {
#   background-color: #006810;
#   color: #f1f1f1;
# }
# #T_b1da7_row18_col1, #T_b1da7_row19_col1 {
#   background-color: #006a0e;
#   color: #f1f1f1;
# }
# #T_b1da7_row20_col1 {
#   background-color: #006c0d;
#   color: #f1f1f1;
# }
# #T_b1da7_row21_col1 {
#   background-color: #006e0c;
#   color: #f1f1f1;
# }
# #T_b1da7_row22_col1 {
#   background-color: #006f0b;
#   color: #f1f1f1;
# }
# #T_b1da7_row23_col1, #T_b1da7_row24_col1 {
#   background-color: #007209;
#   color: #f1f1f1;
# }
# #T_b1da7_row25_col1, #T_b1da7_row26_col1 {
#   background-color: #007408;
#   color: #f1f1f1;
# }
# #T_b1da7_row27_col1, #T_b1da7_row28_col1, #T_b1da7_row29_col1 {
#   background-color: #007507;
#   color: #f1f1f1;
# }
# #T_b1da7_row30_col1, #T_b1da7_row31_col1 {
#   background-color: #007606;
#   color: #f1f1f1;
# }
# #T_b1da7_row32_col1 {
#   background-color: #007a04;
#   color: #f1f1f1;
# }
# #T_b1da7_row33_col1 {
#   background-color: #007b03;
#   color: #f1f1f1;
# }
# #T_b1da7_row34_col1 {
#   background-color: #007c02;
#   color: #f1f1f1;
# }
# #T_b1da7_row35_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1da7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >Smart_Environment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1da7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1da7_row0_col0" class="data row0 col0" >Italy</td>
#       <td id="T_b1da7_row0_col1" class="data row0 col1" >78014</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1da7_row1_col0" class="data row1 col0" >Germany</td>
#       <td id="T_b1da7_row1_col1" class="data row1 col1" >76110</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1da7_row2_col0" class="data row2 col0" >Finland</td>
#       <td id="T_b1da7_row2_col1" class="data row2 col1" >65354</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1da7_row3_col0" class="data row3 col0" >France</td>
#       <td id="T_b1da7_row3_col1" class="data row3 col1" >51054</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1da7_row4_col0" class="data row4 col0" >United States</td>
#       <td id="T_b1da7_row4_col1" class="data row4 col1" >34118</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1da7_row5_col0" class="data row5 col0" >Denmark</td>
#       <td id="T_b1da7_row5_col1" class="data row5 col1" >32738</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1da7_row6_col0" class="data row6 col0" >Canada</td>
#       <td id="T_b1da7_row6_col1" class="data row6 col1" >28595</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1da7_row7_col0" class="data row7 col0" >Norway</td>
#       <td id="T_b1da7_row7_col1" class="data row7 col1" >27652</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1da7_row8_col0" class="data row8 col0" >Sweden</td>
#       <td id="T_b1da7_row8_col1" class="data row8 col1" >24300</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1da7_row9_col0" class="data row9 col0" >United Kingdom</td>
#       <td id="T_b1da7_row9_col1" class="data row9 col1" >20850</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b1da7_row10_col0" class="data row10 col0" >Switzerland</td>
#       <td id="T_b1da7_row10_col1" class="data row10 col1" >17550</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b1da7_row11_col0" class="data row11 col0" >Australia</td>
#       <td id="T_b1da7_row11_col1" class="data row11 col1" >15970</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b1da7_row12_col0" class="data row12 col0" >Spain</td>
#       <td id="T_b1da7_row12_col1" class="data row12 col1" >11210</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b1da7_row13_col0" class="data row13 col0" >China</td>
#       <td id="T_b1da7_row13_col1" class="data row13 col1" >9274</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b1da7_row14_col0" class="data row14 col0" >Japan</td>
#       <td id="T_b1da7_row14_col1" class="data row14 col1" >9274</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b1da7_row15_col0" class="data row15 col0" >South Korea</td>
#       <td id="T_b1da7_row15_col1" class="data row15 col1" >7946</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b1da7_row16_col0" class="data row16 col0" >Austria</td>
#       <td id="T_b1da7_row16_col1" class="data row16 col1" >7608</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b1da7_row17_col0" class="data row17 col0" >Luxembourg</td>
#       <td id="T_b1da7_row17_col1" class="data row17 col1" >7090</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b1da7_row18_col0" class="data row18 col0" >Ireland</td>
#       <td id="T_b1da7_row18_col1" class="data row18 col1" >6494</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b1da7_row19_col0" class="data row19 col0" >Iceland</td>
#       <td id="T_b1da7_row19_col1" class="data row19 col1" >6340</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b1da7_row20_col0" class="data row20 col0" >Belgium</td>
#       <td id="T_b1da7_row20_col1" class="data row20 col1" >5950</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b1da7_row21_col0" class="data row21 col0" >Russia</td>
#       <td id="T_b1da7_row21_col1" class="data row21 col1" >5680</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b1da7_row22_col0" class="data row22 col0" >Netherlands</td>
#       <td id="T_b1da7_row22_col1" class="data row22 col1" >5558</td>
#     </tr>
#     <tr>
#       <th id="T_b1da7_level0_row23" class="row_heading level0 row23" >23

# %%
plt.figure(figsize = (20,15))
labels = x["Country"]
plt.pie(x["Smart_Environment"], autopct = "%.2f", labels = labels)
plt.legend(bbox_to_anchor = (1.27,1))
plt.show()

# %% [markdown]
# Using the data above, we can conclude that Italy is The country with the smartest environment

# %%
canada = data.loc[data["Country"] == "Canada"]
canad =print(canada["SmartCity_Index"].sum())

italy = data.loc[data["Country"] == "Italy"]
ital = print(italy["SmartCity_Index"].sum())

us = data.loc[data["Country"] == "United States"]
u = print(us["SmartCity_Index"].sum())

china = data.loc[data["Country"] == "China"]
chin = print(china["SmartCity_Index"].sum())

germany = data.loc[data["Country"] == "Germany"]
german = print(germany["SmartCity_Index"].sum())

x = [41388, 57667, 45546, 12990, 62195]
plt.figure(figsize = (20,15))
labels = np.array(["Canada", "Italy", "United States", "China", "Germany"])
colors = np.array(["Magenta", "Green", "Blue", "Red", "Yellow"])
plt.pie(x, labels = labels, colors = colors, autopct = "%.2f")

centre_circle = plt.Circle((0,0),0.4,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(bbox_to_anchor = (1,1))
plt.show()
# Out:
# 41388
# 57667
# 45546
# 12990
# 62195

# %%
plt.figure(figsize = (20,15))
sms.violinplot(data = data2, palette = "magma")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (20,15))
sms.boxplot(data = data2, palette = "bright")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (20,15))
sms.barplot(data = data2, palette = "bright")
plt.xticks(rotation = 90)
plt.show()

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
fig.suptitle('Smart Index Bar Plot by Each Country', fontsize=30)
fig.set_size_inches(30,30)
x = ["Netherlands","Norway", "Canada", "Singapore", "Denmark", "Austria", "Sweden", "Switzerland", "Finland", "United States", "Germany", "France", "Luxembourg", "Iceland", "New Zealand" ]
sms.barplot(data = data2, x = x , y = "Smart_Living", palette = "bright", ax = ax1)
sms.barplot(data = data2, x = x , y = "Smart_Mobility ", palette = "dark", ax = ax2)
sms.barplot(data = data2, x = x , y = "Smart_Economy ", palette = "colorblind", ax = ax3)
sms.barplot(data = data2, x = x , y = "Smart_Government ", palette = "pastel", ax = ax4)
sms.barplot(data = data2, x = x , y = "Smart_People", palette = "deep", ax = ax5)
sms.barplot(data = data2, x = x , y = "Smart_Environment", palette = "muted", ax = ax6)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax1.set_title(label="Smart Living", fontdict={'size': 20})
ax2.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax2.set_title(label="Smart Mobility", fontdict={'size': 20})
ax3.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax3.set_title(label="Smart Economy", fontdict={'size': 20})
ax4.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax4.set_title(label="Smart Government", fontdict={'size': 20})
ax5.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax5.set_title(label="Smart People", fontdict={'size': 20})
ax6.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax6.set_title(label="Smart Environment", fontdict={'size': 20})
plt.show()

# %%
plt.figure(figsize = (15,10))
sms.heatmap(data = data2, annot = True, annot_kws={"size":10}, fmt="", cmap = "tab20", linewidths = 2)
plt.show()

# %%
data2 = data2.drop(["SmartCity_Index_relative_Edmonton"], axis = 1)

# %%
map2 = fl.Map(location = (11.1271, 78.6569), zoom_start = 12)
fl.CircleMarker(location = (11.1271, 78.6569), radius = 50, popup = "<h4><b>Tamil Nadu").add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664cd9c7a55cf7b6fa5ac9f4d88937ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664cd9c7a55cf7b6fa5ac9f4d88937ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_664cd9c7a55cf7b6fa5ac9f4d88937ec = L.map(
#                 &quot;map_664cd9c7a55cf7b6fa5ac9f4d88937ec&quot;,
#                 {
#                     center: [11.1271, 78.6569],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff5084be84b7ee358f921d0b1baa72ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_664cd9c7a55cf7b6fa5ac9f4d88937ec);
#
#
#             var circle_marker_36762722f7d880a191a2edfa8cb0bc40 = L.circleMarker(
#                 [11.1271, 78.6569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_664cd9c7a55cf7b6fa5ac9f4d88937ec);
#
#
#         var popup_a74789dedda4de8c1ec5952b84c06aec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f096ed2717d11b779b491de3dd53aef6 = $(`&lt;div id=&quot;html_f096ed2717d11b779b491de3dd53aef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Tamil Nadu&lt;/div&gt;`)[0];
#             popup_a74789dedda4de8c1ec5952b84c06aec.setContent(html_f096ed2717d11b779b491de3dd53aef6);
#
#
#         circle_marker_36762722f7d880a191a2edfa8cb0bc40.bindPopup(popup_a74789dedda4de8c1ec5952b84c06aec)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map3 = fl.Map(location = [48.8566, 2.3522], zoom_start = 10)
fl.Marker(location = [48.8566, 2.3522], popup = "<h3> <b>Paris").add_to(map3)
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d2a49b452bb86eef785554dba3a28a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d2a49b452bb86eef785554dba3a28a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1d2a49b452bb86eef785554dba3a28a7 = L.map(
#                 &quot;map_1d2a49b452bb86eef785554dba3a28a7&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24f36a89654aa2df7074e0e7acf6cc22 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d2a49b452bb86eef785554dba3a28a7);
#
#
#             var marker_32baeaca0370738700a72a2472f5dd01 = L.marker(
#                 [48.8566, 2.3522],
#                 {}
#             ).addTo(map_1d2a49b452bb86eef785554dba3a28a7);
#
#
#         var popup_a701b0f7a65a39f85c163649bdcd6a2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5f10bafe0eb1e488c7a2f4f125498688 = $(`&lt;div id=&quot;html_5f10bafe0eb1e488c7a2f4f125498688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3&gt; &lt;b&gt;Paris&lt;/div&gt;`)[0];
#             popup_a701b0f7a65a39f85c163649bdcd6a2c.setContent(html_5f10bafe0eb1e488c7a2f4f125498688);
#
#
#         marker_32baeaca0370738700a72a2472f5dd01.bindPopup(popup_a701b0f7a65a39f85c163649bdcd6a2c)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map4 = fl.Map(location = (11.1271, 78.6569), zoom_start = 7)
fl.Marker(location = (11.1271, 78.6569), popup = "<h3><b>Tamil Nadu").add_to(map4)
fl.Marker(location = (48.8566, 2.3522), popup = "<h3><b>Paris").add_to(map4)
fl.PolyLine(locations = [(11.1271, 78.6569), (48.8566, 2.3522)]).add_to(map4)
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9225e663fc13aa96624a92672bfb404d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9225e663fc13aa96624a92672bfb404d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9225e663fc13aa96624a92672bfb404d = L.map(
#                 &quot;map_9225e663fc13aa96624a92672bfb404d&quot;,
#                 {
#                     center: [11.1271, 78.6569],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e6352cd04526bc24b21690cdeb26191 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9225e663fc13aa96624a92672bfb404d);
#
#
#             var marker_72fe2ab28fcc88e3f07e60f01422d541 = L.marker(
#                 [11.1271, 78.6569],
#                 {}
#             ).addTo(map_9225e663fc13aa96624a92672bfb404d);
#
#
#         var popup_c6aca4787e482abbccb97142d88b942a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9867f40adf350da9bfd094c55fefe588 = $(`&lt;div id=&quot;html_9867f40adf350da9bfd094c55fefe588&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3&gt;&lt;b&gt;Tamil Nadu&lt;/div&gt;`)[0];
#             popup_c6aca4787e482abbccb97142d88b942a.setContent(html_9867f40adf350da9bfd094c55fefe588);
#
#
#         marker_72fe2ab28fcc88e3f07e60f01422d541.bindPopup(popup_c6aca4787e482abbccb97142d88b942a)
#         ;
#
#
#
#
#             var marker_4f489c935a8675254cbff5d041c3d2a8 = L.marker(
#                 [48.8566, 2.3522],
#                 {}
#             ).addTo(map_9225e663fc13aa96624a92672bfb404d);
#
#
#         var popup_e08f55dee46a8c5a0a7307e263ae852f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5855f2f0c28b102329ca4f983d14c08a = $(`&lt;div id=&quot;html_5855f2f0c28b102329ca4f983d14c08a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3&gt;&lt;b&gt;Paris&lt;/div&gt;`)[0];
#             popup_e08f55dee46a8c5a0a7307e263ae852f.setContent(html_5855f2f0c28b102329ca4f983d14c08a);
#
#
#         marker_4f489c935a8675254cbff5d041c3d2a8.bindPopup(popup_e08f55dee46a8c5a0a7307e263ae852f)
#         ;
#
#
#
#
#             var poly_line_a05a734b86d118aa4944b0d64577b297 = L.polyline(
#                 [[11.1271, 78.6569], [48.8566, 2.3522]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9225e663fc13aa96624a92672bfb404d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data2 = data.groupby("Country").median().astype(int).sort_values("SmartCity_Index", ascending = False).head(14)
data2.style.background_gradient(cmap = "GnBu")
# Out:
# <style type="text/css">
# #T_b9533_row0_col0, #T_b9533_row1_col4, #T_b9533_row3_col2, #T_b9533_row9_col3, #T_b9533_row12_col1, #T_b9533_row12_col5, #T_b9533_row13_col6, #T_b9533_row13_col7, #T_b9533_row13_col8 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_b9533_row0_col1 {
#   background-color: #084586;
#   color: #f1f1f1;
# }
# #T_b9533_row0_col2, #T_b9533_row5_col3, #T_b9533_row9_col6 {
#   background-color: #c5e8c2;
#   color: #000000;
# }
# #T_b9533_row0_col3, #T_b9533_row0_col7, #T_b9533_row0_col8, #T_b9533_row3_col5, #T_b9533_row3_col6, #T_b9533_row7_col2, #T_b9533_row9_col1, #T_b9533_row11_col0, #T_b9533_row13_col4 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_b9533_row0_col4, #T_b9533_row5_col2 {
#   background-color: #2f90c0;
#   color: #f1f1f1;
# }
# #T_b9533_row0_col5, #T_b9533_row0_col6 {
#   background-color: #83cfc1;
#   color: #000000;
# }
# #T_b9533_row1_col0, #T_b9533_row3_col3, #T_b9533_row5_col0 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_b9533_row1_col1, #T_b9533_row11_col2, #T_b9533_row13_col3 {
#   background-color: #3699c5;
#   color: #f1f1f1;
# }
# #T_b9533_row1_col2 {
#   background-color: #58b9d0;
#   color: #000000;
# }
# #T_b9533_row1_col3 {
#   background-color: #72c7c7;
#   color: #000000;
# }
# #T_b9533_row1_col5 {
#   background-color: #4fb3d3;
#   color: #f1f1f1;
# }
# #T_b9533_row1_col6 {
#   background-color: #1576b3;
#   color: #f1f1f1;
# }
# #T_b9533_row1_col7, #T_b9533_row1_col8 {
#   background-color: #1a7ab5;
#   color: #f1f1f1;
# }
# #T_b9533_row2_col0 {
#   background-color: #bae4bd;
#   color: #000000;
# }
# #T_b9533_row2_col1, #T_b9533_row8_col0 {
#   background-color: #2586bb;
#   color: #f1f1f1;
# }
# #T_b9533_row2_col2 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_b9533_row2_col3 {
#   background-color: #abdeb6;
#   color: #000000;
# }
# #T_b9533_row2_col4 {
#   background-color: #94d5bc;
#   color: #000000;
# }
# #T_b9533_row2_col5 {
#   background-color: #8fd4bd;
#   color: #000000;
# }
# #T_b9533_row2_col6 {
#   background-color: #084485;
#   color: #f1f1f1;
# }
# #T_b9533_row2_col7, #T_b9533_row2_col8 {
#   background-color: #4db2d3;
#   color: #f1f1f1;
# }
# #T_b9533_row3_col0, #T_b9533_row9_col2 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_b9533_row3_col1 {
#   background-color: #70c6c8;
#   color: #000000;
# }
# #T_b9533_row3_col4 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_b9533_row3_col7, #T_b9533_row3_col8 {
#   background-color: #5ebcce;
#   color: #000000;
# }
# #T_b9533_row4_col0 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_b9533_row4_col1 {
#   background-color: #68c1ca;
#   color: #000000;
# }
# #T_b9533_row4_col2 {
#   background-color: #0868ac;
#   color: #f1f1f1;
# }
# #T_b9533_row4_col3 {
#   background-color: #3c9fc8;
#   color: #f1f1f1;
# }
# #T_b9533_row4_col4 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_b9533_row4_col5, #T_b9533_row7_col0 {
#   background-color: #b4e2ba;
#   color: #000000;
# }
# #T_b9533_row4_col6 {
#   background-color: #88d1c0;
#   color: #000000;
# }
# #T_b9533_row4_col7, #T_b9533_row4_col8 {
#   background-color: #61bdcd;
#   color: #000000;
# }
# #T_b9533_row5_col1 {
#   background-color: #7accc4;
#   color: #000000;
# }
# #T_b9533_row5_col4 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_b9533_row5_col5 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_b9533_row5_col6 {
#   background-color: #73c8c7;
#   color: #000000;
# }
# #T_b9533_row5_col7, #T_b9533_row5_col8, #T_b9533_row6_col7, #T_b9533_row6_col8, #T_b9533_row9_col4, #T_b9533_row12_col0 {
#   background-color: #6bc3c9;
#   color: #000000;
# }
# #T_b9533_row6_col0, #T_b9533_row10_col6 {
#   background-color: #d8f0d3;
#   color: #000000;
# }
# #T_b9533_row6_col1, #T_b9533_row6_col4, #T_b9533_row8_col5 {
#   background-color: #cdebc6;
#   color: #000000;
# }
# #T_b9533_row6_col2 {
#   background-color: #0862a5;
#   color: #f1f1f1;
# }
# #T_b9533_row6_col3 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_b9533_row6_col5, #T_b9533_row7_col1 {
#   background-color: #9cd9b9;
#   color: #000000;
# }
# #T_b9533_row6_col6 {
#   background-color: #64bfcc;
#   color: #000000;
# }
# #T_b9533_row7_col3 {
#   background-color: #eaf7e4;
#   color: #000000;
# }
# #T_b9533_row7_col4 {
#   background-color: #bbe4bd;
#   color: #000000;
# }
# #T_b9533_row7_col5 {
#   background-color: #b2e1b9;
#   color: #000000;
# }
# #T_b9533_row7_col6 {
#   background-color: #54b6d1;
#   color: #f1f1f1;
# }
# #T_b9533_row7_col7, #T_b9533_row7_col8, #T_b9533_row8_col2 {
#   background-color: #7fcdc3;
#   color: #000000;
# }
# #T_b9533_row8_col1 {
#   background-color: #addfb7;
#   color: #000000;
# }
# #T_b9533_row8_col3 {
#   background-color: #ceecc7;
#   color: #000000;
# }
# #T_b9533_row8_col4, #T_b9533_row8_col6, #T_b9533_row10_col2 {
#   background-color: #2a8bbe;
#   color: #f1f1f1;
# }
# #T_b9533_row8_col7, #T_b9533_row8_col8 {
#   background-color: #84cfc1;
#   color: #000000;
# }
# #T_b9533_row9_col0 {
#   background-color: #afe0b8;
#   color: #000000;
# }
# #T_b9533_row9_col5 {
#   background-color: #a6dcb6;
#   color: #000000;
# }
# #T_b9533_row9_col7, #T_b9533_row9_col8 {
#   background-color: #c8eac3;
#   color: #000000;
# }
# #T_b9533_row10_col0 {
#   background-color: #42a6cc;
#   color: #f1f1f1;
# }
# #T_b9533_row10_col1 {
#   background-color: #40a4cb;
#   color: #f1f1f1;
# }
# #T_b9533_row10_col3 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_b9533_row10_col4 {
#   background-color: #91d4bd;
#   color: #000000;
# }
# #T_b9533_row10_col5, #T_b9533_row12_col7, #T_b9533_row12_col8 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_b9533_row10_col7, #T_b9533_row10_col8 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_b9533_row11_col1 {
#   background-color: #80cec2;
#   color: #000000;
# }
# #T_b9533_row11_col3 {
#   background-color: #b6e3bb;
#   color: #000000;
# }
# #T_b9533_row11_col4 {
#   background-color: #57b8d0;
#   color: #000000;
# }
# #T_b9533_row11_col5 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_b9533_row11_col6 {
#   background-color: #a7ddb5;
#   color: #000000;
# }
# #T_b9533_row11_col7, #T_b9533_row11_col8 {
#   background-color: #ddf2d7;
#   color: #000000;
# }
# #T_b9533_row12_col2 {
#   background-color: #50b4d2;
#   color: #f1f1f1;
# }
# #T_b9533_row12_col3 {
#   background-color: #085c9f;
#   color: #f1f1f1;
# }
# #T_b9533_row12_col4 {
#   background-color: #1878b4;
#   color: #f1f1f1;
# }
# #T_b9533_row12_col6 {
#   background-color: #a2dbb7;
#   color: #000000;
# }
# #T_b9533_row13_col0 {
#   background-color: #98d7ba;
#   color: #000000;
# }
# #T_b9533_row13_col1 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_b9533_row13_col2 {
#   background-color: #8dd3be;
#   color: #000000;
# }
# #T_b9533_row13_col5 {
#   background-color: #76c9c6;
#   color: #000000;
# }
# </style>
# <table id="T_b9533_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >Smart_Mobility </th>
#       <th class="col_heading level0 col2" >Smart_Environment</th>
#       <th class="col_heading level0 col3" >Smart_Government </th>
#       <th class="col_heading level0 col4" >Smart_Economy </th>
#       <th class="col_heading level0 col5" >Smart_People</th>
#       <th class="col_heading level0 col6" >Smart_Living</th>
#       <th class="col_heading level0 col7" >SmartCity_Index</th>
#       <th class="col_heading level0 col8" >SmartCity_Index_relative_Edmonton</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9533_level0_row0" class="row_heading level0 row0" >Netherlands</th>
#       <td id="T_b9533_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_b9533_row0_col1" class="data row0 col1" >7540</td>
#       <td id="T_b9533_row0_col2" class="data row0 col2" >5558</td>
#       <td id="T_b9533_row0_col3" class="data row0 col3" >8528</td>
#       <td id="T_b9533_row0_col4" class="data row0 col4" >8095</td>
#       <td id="T_b9533_row0

# %%
lat = [52.1326, 60.4720, 56.130367, 1.3521, 56.2639, 47.5162, 60.1282, 46.8182, 61.9241, 37.090240, 51.1657, 46.227638, 49.8153, 64.9631]
lon = [5.2913, 8.4689, -106.346771, 103.8198, 9.5018, 14.5501, 18.6435, 8.2275, 25.7482, -95.712891, 10.4515, 2.213749, 6.1296, 19.0208]
Country = ["Netherlands","Norway", "Canada", "Singapore", "Denmark", "Austria", "Sweden", "Switzerland", "Finland", "United States", "Germany", "France", "Luxembourg", "Iceland"]
#data2.insert(2,"Latitude", lat)
#data2.insert(2,"Longitude", lon)
#data2.insert(2,"Country", Country)
print(data2)
# Out:
#                Id  Smart_Mobility    Latitude   Longitude        Country  \
# Country
# Netherlands     3             7540  52.132600    5.291300    Netherlands
# Norway          7             6486  60.472000    8.468900         Norway
# Canada         21             6727  56.130367 -106.346771         Canada
# Singapore       9             5790   1.352100  103.819800      Singapore
# Denmark        11             5876  56.263900    9.501800        Denmark
# Austria         7             5683  47.516200   14.550100        Austria
# Sweden         13             4683  60.128200   18.643500         Sweden
# Switzerland    22             5326  46.818200    8.227500    Switzerland
# Finland        47             5124  61.924100   25.748200        Finland
# United States  23             7607  37.090240  -95.712891  United States
# Germany        41             6342  51.165700   10.451500        Germany
# France         60             5620  46.227638    2.213749         France
# Luxembourg     34             3747  49.815300    6.129600     Luxembourg
# Iceland        27             3785  64.963100   19.020800        Iceland
#
#                Smart_Environment  Smart_Government   Smart_Economy   \
# Country
# Netherlands                 5558               8528            8095
# Norway                      6989               7018            4925
# Canada                      4780               6510            6782
# Singapore                   4344               5560            5535
# Denmark                     8207               7540            5182
# Austria                     7608               6232            5415
# Sweden                      8296               7840            5980
# Switzerland                 8775               5591            6265
# Finland                     6519               6121            8155
# United States               4800               5356            7265
# Germany                     7673               5989            6812
# France                      7480               6396            7495
# Luxembourg                  7090               8254            8440
# Iceland                     6340               7604            9225
#
#                Smart_People  Smart_Living  SmartCity_Index  \
# Country
# Netherlands            7098          7280             7311
# Norway                 7822          9090             7088
# Canada                 6930          9920             6866
# Singapore              9695         10000             6813
# Denmark                6386          7200             6803
# Austria                8580          7500             6771
# Sweden                 6743          7730             6771
# Switzerland            6425          7960             6707
# Finland                5944          8710             6689
# United States          6610          6220             6437
# Germany                5274          5690             6334
# France                 5675          6750             6296
# Luxembourg             4723          6820             6255
# Iceland                7285          4780             6124
#
#                SmartCity_Index_relative_Edmonton
# Country
# Netherlands                                  839
# Norway                                       616
# Canada                                       394
# Singapore                                    341
# Denmark                                      330
# Austria                                      298
# Sweden                                       299
# Switzerland                                  235
# Finland                                      217
# United States                                -35
# Germany                                     -137
# France                                      -176
# Luxembourg                                  -217
# Iceland                                     -348

# %%
map = fl.Map(location = (64.9631, 19.0208), zoom_start = 3)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fe4f992ac02efafd8b8000931402b4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fe4f992ac02efafd8b8000931402b4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7fe4f992ac02efafd8b8000931402b4a = L.map(
#                 &quot;map_7fe4f992ac02efafd8b8000931402b4a&quot;,
#                 {
#                     center: [64.9631, 19.0208],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed8c8fab7d3feecf8d28b2390fc59122 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
x = ["Netherlands","Norway", "Canada", "Singapore", "Denmark", "Austria", "Sweden", "Switzerland", "Finland", "United States", "Germany", "France", "Luxembourg", "Iceland" ]
for lat,lon,sc_index, country in zip(data2["Latitude"], data2["Longitude"], data2["SmartCity_Index"], x):
  fl.Marker(location = [lat,lon], popup= ("Country", country, "\nSmartCity_Index", sc_index, )).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fe4f992ac02efafd8b8000931402b4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fe4f992ac02efafd8b8000931402b4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7fe4f992ac02efafd8b8000931402b4a = L.map(
#                 &quot;map_7fe4f992ac02efafd8b8000931402b4a&quot;,
#                 {
#                     center: [64.9631, 19.0208],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed8c8fab7d3feecf8d28b2390fc59122 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
#
#             var marker_a2a033203c4e383970a66fa7b47d52c5 = L.marker(
#                 [52.1326, 5.2913],
#                 {}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
#
#         var popup_f1e329f2e939db67c116b05da9041791 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_486b5864498fe99efed939a9499cb1c2 = $(`&lt;div id=&quot;html_486b5864498fe99efed939a9499cb1c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Country&#x27;, &#x27;Netherlands&#x27;, &#x27;\nSmartCity_Index&#x27;, 7311)&lt;/div&gt;`)[0];
#             popup_f1e329f2e939db67c116b05da9041791.setContent(html_486b5864498fe99efed939a9499cb1c2);
#
#
#         marker_a2a033203c4e383970a66fa7b47d52c5.bindPopup(popup_f1e329f2e939db67c116b05da9041791)
#         ;
#
#
#
#
#             var marker_d562e42a00f0375951ada054ac2d026a = L.marker(
#                 [60.472, 8.4689],
#                 {}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
#
#         var popup_5450da20944660ed1810228cfd9c527a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_645a9f573d38208df9ff47e5a265e730 = $(`&lt;div id=&quot;html_645a9f573d38208df9ff47e5a265e730&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Country&#x27;, &#x27;Norway&#x27;, &#x27;\nSmartCity_Index&#x27;, 7088)&lt;/div&gt;`)[0];
#             popup_5450da20944660ed1810228cfd9c527a.setContent(html_645a9f573d38208df9ff47e5a265e730);
#
#
#         marker_d562e42a00f0375951ada054ac2d026a.bindPopup(popup_5450da20944660ed1810228cfd9c527a)
#         ;
#
#
#
#
#             var marker_7c484acec5f345eed3c6a51e969e3af2 = L.marker(
#                 [56.130367, -106.346771],
#                 {}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
#
#         var popup_70c9ac6e4011821e5a694b919a11d954 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c4698e5f2433ce96493dbe2d980ef4c9 = $(`&lt;div id=&quot;html_c4698e5f2433ce96493dbe2d980ef4c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Country&#x27;, &#x27;Canada&#x27;, &#x27;\nSmartCity_Index&#x27;, 6866)&lt;/div&gt;`)[0];
#             popup_70c9ac6e4011821e5a694b919a11d954.setContent(html_c4698e5f2433ce96493dbe2d980ef4c9);
#
#
#         marker_7c484acec5f345eed3c6a51e969e3af2.bindPopup(popup_70c9ac6e4011821e5a694b919a11d954)
#         ;
#
#
#
#
#             var marker_ebd461cff1bfdce87dd442021cfa4ad1 = L.marker(
#                 [1.3521, 103.8198],
#                 {}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
#
#         var popup_455be25c5ed9785a1d423c5a5a49765a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9fdeff3d31a2e4cfd0e4b383bd19d19b = $(`&lt;div id=&quot;html_9fdeff3d31a2e4cfd0e4b383bd19d19b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Country&#x27;, &#x27;Singapore&#x27;, &#x27;\nSmartCity_Index&#x27;, 6813)&lt;/div&gt;`)[0];
#             popup_455be25c5ed9785a1d423c5a5a49765a.setContent(html_9fdeff3d31a2e4cfd0e4b383bd19d19b);
#
#
#         marker_ebd461cff1bfdce87dd442021cfa4ad1.bindPopup(popup_455be25c5ed9785a1d423c5a5a49765a)
#         ;
#
#
#
#
#             var marker_6b7826867c5c5bf7a4c90194f7ec1482 = L.marker(
#                 [56.2639, 9.5018],
#                 {}
#             ).addTo(map_7fe4f992ac02efafd8b8000931402b4a);
#
#
#         var popup_0b1abc878e115b1039f09468c317b47c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a24641d104380f87e85d1138d23f9a68 = $(`&lt;div id=&quot;html_a24641d104380f87e85d1138d23f9a68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Country&#x27;, &#x27;Denmark&#x27;, &#x27;\nSmartCity_Index&#x27;, 6803)&lt;/div&gt;`)[0];
#             popup_0b1abc878e115b1039f09468c317b47c.setContent(html_a24641d104380f87e85d1138d23f9a68);
#
#
#         marker_6b7826867c5c5bf7a4c90194f7ec1482.bindPopup(popup_0b1abc878e115b1039f09468c317b47c)
#         ;
#
#
#
#
#             var marker_4f5b39956092aab82df1ee6b23c47f82 = L.marker(
#                 [47.5162, 14.5501],
#                 {

# %%
plt.figure(figsize = (50,50))
x = ["Netherlands","Norway", "Canada", "Singapore", "Denmark", "Austria", "Sweden", "Switzerland", "Finland", "United States", "Germany", "France", "Luxembourg", "Iceland"]
sms.pairplot(data2)
plt.show()

# %%
fig = px.bar(data2, x = "SmartCity_Index", y = "Country",title = "Smart City Index of Countries", text = "SmartCity_Index", orientation = "h",
             width = 1250, height = 750, range_x = [0,max(data2["SmartCity_Index"])])
fig.update_traces(textposition = "inside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="aa70594b-8dbe-4a93-b8e6-546bcca15c52" class="plotly-graph-div" style="height:750px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa70594b-8dbe-4a93-b8e6-546bcca15c52")) {                    Plotly.newPlot(                        "aa70594b-8dbe-4a93-b8e6-546bcca15c52",                        [{"alignmentgroup":"True","hovertemplate":"SmartCity_Index=%{text}<br>Country=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[7311.0,7088.0,6866.0,6813.0,6803.0,6771.0,6771.0,6707.0,6689.0,6437.0,6334.0,6296.0,6255.0,6124.0],"textposition":"inside","x":[7311,7088,6866,6813,6803,6771,6771,6707,6689,6437,6334,6296,6255,6124],"xaxis":"x","y":["Netherlands","Norway","Canada","Singapore","Denmark","Austria","Sweden","Switzerland","Finland","United States","Germany","France","Luxembourg","Iceland"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorb ...

# %%
var = data.groupby("Country")["Smart_Living"].sum().reset_index()
fig = px.scatter(var,x = "Country", y = "Smart_Living", color = "Smart_Living", size = "Smart_Living", hover_data = ["Smart_Living"], color_discrete_sequence = px.colors.cyclical.IceFire)
fig.update_layout(title_text = "Smart Living Index by Country", plot_bgcolor = "turquoise", width = 1500, height = 750)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="17177ec9-f39a-4b6c-8335-6c8894167cd2" class="plotly-graph-div" style="height:750px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17177ec9-f39a-4b6c-8335-6c8894167cd2")) {                    Plotly.newPlot(                        "17177ec9-f39a-4b6c-8335-6c8894167cd2",                        [{"hovertemplate":"Country=%{x}<br>Smart_Living=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[38480,7500,4250,56478,5940,4930,28800,7810,87100,47250,56900,3120,4780,7430,2360,43450,18640,4330,6820,8790,7280,9170,36360,4860,8200,10000,2440,4180,9420,5480,23190,15920,7350,4260,13650,43540],"coloraxis":"coloraxis","size":[38480,7500,4250,56478,5940,4930,28800,7810,87100,47250,56900,3120,4780,7430,2360,43450,18640,4330,6820,8790,7280,9170,36360,4860,8200,10000,2440,4180,9420,5480,23190,15920,7350,4260,13650,43540],"sizemode":"area","sizeref":217.75,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Australia","Austria","Belgium","Canada","China","Czech Republic","Denmark","Estonia","Finland","France","Germany","Hungary","Iceland","Ireland","Israel","Italy","Japan","Latvia","Luxembourg","Malaysia","Netherlands","New Zealand","Norway","Portugal","Russia","Singapore","Slovakia","Slovenia","South Korea","Spain","Sweden","Switzerland","Taiwan","United Arab Emirates","United Kingdom","United States"],"xaxis":"x","y":[38480,7500,4250,56478,5940,4930,28800,7810,87100,47250,56900,3120,4780,7430,2360,43450,18640,4330,6820,8790,7280,9170,36360,4860,8200,10000,2440,4180,9420,5480,23190,15920,7350,4260,13650,43540],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...
